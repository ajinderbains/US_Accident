# %%
import pandas as pd
import datetime as dt

# %%
#Bring in cleaned sample from CSV
df_edit_sample_2=pd.read_csv("./df_edit_sample.csv")
df_edit_sample_2
# Out:
#         Original_Index         ID  Severity        Start_Time  \
# 0              3490633  A-3490797         2    7/5/2019 10:41
# 1              1485927  A-1485959         3   12/28/2018 8:27
# 2              2950422  A-2950571         2    1/7/2020 13:58
# 3               153637   A-153639         2    9/26/2016 8:08
# 4               107913   A-107915         3   5/19/2016 22:08
# ...                ...        ...       ...               ...
# 499995         1383866  A-1383897         2    1/4/2019 13:20
# 499996         1113299  A-1113325         3    6/12/2019 8:03
# 499997         1486192  A-1486224         2  12/28/2018 10:49
# 499998         2293957  A-2293997         2   10/6/2017 14:56
# 499999           81502    A-81504         2   10/4/2016 16:05
#
#                 End_Time State Country  Visibility(mi) Weather_Condition  \
# 0         7/5/2019 11:39    UT      US            10.0              Fair
# ...

# %%
#Select 100k sample rows
df_sample_100k = df_edit_sample_2.sample(n = 100000)
df_sample_100k
# Out:
#         Original_Index         ID  Severity        Start_Time  \
# 316354         2484276  A-2484317         2   3/23/2016 17:30
# 423250          775151   A-775176         2  12/11/2019 19:36
# 375274         1749035  A-1749069         2    7/2/2018 19:16
# 63565          1499604  A-1499636         2    11/5/2018 8:32
# 339022         1233521  A-1233549         2    4/15/2019 7:28
# ...                ...        ...       ...               ...
# 138888          534015   A-534023         2   5/13/2020 16:41
# 322368          559317   A-559325         2   6/29/2020 16:33
# 105662         2358381  A-2358421         2    9/7/2017 13:46
# 408389         2954437  A-2954586         2    1/10/2020 7:04
# 245898         1850446  A-1850484         2   6/26/2018 16:07
#
#                 End_Time State Country  Visibility(mi) Weather_Condition  \
# 316354   3/23/2016 23:30    CA      US            10.0             Clear
# ...

# %%
df_sample_100k.to_csv(r'C:\BootcampUCB\Final Project\df_small_sample.csv', index = False)
