# %%
import pandas as pd
import datetime as dt

# %%
#Bring in original sample from CSV
df=pd.read_csv("./US_Accidents_June20.csv")
df.head(5)
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                      1034799
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  2478818
# End_Lng                  2478818
# Distance(mi)                   0
# Description                    1
# Number                   2262864
# Street                         0
# Side                           0
# City                         112
# County                         0
# State                          0
# Zipcode                     1069
# Country                        0
# Timezone                    3880
# Airport_Code                6758
# Weather_Timestamp          43323
# Temperature(F)             65732
# Wind_Chill(F)            1868249
# Humidity(%)                69687
# Pressure(in)               55882
# Visibility(mi)             75856
# ...

# %%
#Drop columns with signifiant amounts of null values
df_new=df.drop(['TMC', 'End_Lat', 'End_Lng', 'Number', 'Wind_Chill(F)', 'Precipitation(in)'], axis=1)
df_new
# Out:
#                 ID    Source  Severity           Start_Time  \
# 0              A-1  MapQuest         3  2016-02-08 05:46:00
# 1              A-2  MapQuest         2  2016-02-08 06:07:59
# 2              A-3  MapQuest         2  2016-02-08 06:49:27
# 3              A-4  MapQuest         3  2016-02-08 07:23:34
# 4              A-5  MapQuest         2  2016-02-08 07:39:07
# ...            ...       ...       ...                  ...
# 3513612  A-3513776      Bing         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723         0.010
# 1        2016-02-08 06:37:59  39.928059  -82.831184         0.010
# ...

# %%
df_new.isnull().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# Distance(mi)                  0
# Description                   1
# Street                        0
# Side                          0
# City                        112
# County                        0
# State                         0
# Zipcode                    1069
# Country                       0
# Timezone                   3880
# Airport_Code               6758
# Weather_Timestamp         43323
# Temperature(F)            65732
# Humidity(%)               69687
# Pressure(in)              55882
# Visibility(mi)            75856
# Wind_Direction            58874
# Wind_Speed(mph)          454609
# Weather_Condition         76138
# Amenity                       0
# Bump                          0
# Crossing                      0
# ...

# %%
#Drop rows with null values
df_clean=df_new.dropna()
df_clean
# Out:
#                 ID    Source  Severity           Start_Time  \
# 2              A-3  MapQuest         2  2016-02-08 06:49:27
# 3              A-4  MapQuest         3  2016-02-08 07:23:34
# 4              A-5  MapQuest         2  2016-02-08 07:39:07
# 5              A-6  MapQuest         3  2016-02-08 07:44:26
# 6              A-7  MapQuest         2  2016-02-08 07:59:35
# ...            ...       ...       ...                  ...
# 3513612  A-3513776      Bing         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 2        2016-02-08 07:19:27  39.063148  -84.032608         0.010
# 3        2016-02-08 07:53:34  39.747753  -84.205582         0.010
# ...

# %%
df_clean.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# Side                     0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Weather_Timestamp        0
# Temperature(F)           0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# ...

# %%
df_clean.dtypes
# Out:
# ID                        object
# Source                    object
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# Description               object
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# ...

# %%
#Select 500k sample rows
df_sample = df_clean.sample(n = 500000)
df_sample
# Out:
#                 ID    Source  Severity           Start_Time  \
# 3490633  A-3490797      Bing         2  2019-07-05 10:41:00
# 1485927  A-1485959  MapQuest         3  2018-12-28 08:27:18
# 2950422  A-2950571      Bing         2  2020-01-07 13:58:19
# 153637    A-153639  MapQuest         2  2016-09-26 08:08:03
# 107913    A-107915  MapQuest         3  2016-05-19 22:08:20
# ...            ...       ...       ...                  ...
# 1383866  A-1383897  MapQuest         2  2019-01-04 13:20:04
# 1113299  A-1113325  MapQuest         3  2019-06-12 08:03:30
# 1486192  A-1486224  MapQuest         2  2018-12-28 10:49:47
# 2293957  A-2293997  MapQuest         2  2017-10-06 14:56:55
# 81502      A-81504  MapQuest         2  2016-10-04 16:05:05
#
#                     End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 3490633  2019-07-05 11:39:00  40.816990 -111.918890         0.333
# 1485927  2018-12-28 08:56:49  30.502701  -87.229202         0.110
# ...

# %%
df_sample.to_csv(r'C:\BootcampUCB\Final Project\df_sample_full.csv', index = True)

# %%
pd.set_option('display.max_columns', None)
df_sample.head()
# Out:
#                 ID    Source  Severity           Start_Time  \
# 3490633  A-3490797      Bing         2  2019-07-05 10:41:00
# 1485927  A-1485959  MapQuest         3  2018-12-28 08:27:18
# 2950422  A-2950571      Bing         2  2020-01-07 13:58:19
# 153637    A-153639  MapQuest         2  2016-09-26 08:08:03
# 107913    A-107915  MapQuest         3  2016-05-19 22:08:20
#
#                     End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 3490633  2019-07-05 11:39:00  40.816990 -111.918890         0.333
# 1485927  2018-12-28 08:56:49  30.502701  -87.229202         0.110
# 2950422  2020-01-07 14:27:03  37.558680  -79.658740         0.802
# 153637   2016-09-26 08:37:07  33.832123  -84.335274         0.000
# 107913   2016-05-19 22:38:20  33.916611 -118.191299         0.000
#
#                                                Description    Street Side  \
# 3490633                      At US-89/Exit 312 - Accident.    I-15 N    R
# ...

# %%
#Trim down number of columns
df_sample_trim=pd.DataFrame(
    data=df,columns=['ID', 'Severity','Start_Time', 'End_Time', 'State', 'Country', 'Visibility(mi)', 'Weather_Condition', 'Sunrise_Sunset', 'Civil_Twilight'],index=df_sample.index.copy())
df_sample_trim
# Out:
#                 ID  Severity           Start_Time             End_Time State  \
# 3490633  A-3490797         2  2019-07-05 10:41:00  2019-07-05 11:39:00    UT
# 1485927  A-1485959         3  2018-12-28 08:27:18  2018-12-28 08:56:49    FL
# 2950422  A-2950571         2  2020-01-07 13:58:19  2020-01-07 14:27:03    VA
# 153637    A-153639         2  2016-09-26 08:08:03  2016-09-26 08:37:07    GA
# 107913    A-107915         3  2016-05-19 22:08:20  2016-05-19 22:38:20    CA
# ...            ...       ...                  ...                  ...   ...
# 1383866  A-1383897         2  2019-01-04 13:20:04  2019-01-04 14:04:52    SC
# 1113299  A-1113325         3  2019-06-12 08:03:30  2019-06-12 09:02:35    FL
# 1486192  A-1486224         2  2018-12-28 10:49:47  2018-12-28 11:34:33    AZ
# 2293957  A-2293997         2  2017-10-06 14:56:55  2017-10-06 15:56:35    MA
# 81502      A-81504         2  2016-10-04 16:05:05  2016-10-04 16:35:05    CA
#
# ...

# %%
df_sample_trim.to_csv(r'C:\BootcampUCB\Final Project\df_sample_trim.csv', index = True)

# %%
#Bring in cleaned sample from CSV
df_edit_sample=pd.read_csv("./df_sample_trim.csv")
df_edit_sample
# Out:
#         Unnamed: 0         ID  Severity           Start_Time  \
# 0          3490633  A-3490797         2  2019-07-05 10:41:00
# 1          1485927  A-1485959         3  2018-12-28 08:27:18
# 2          2950422  A-2950571         2  2020-01-07 13:58:19
# 3           153637   A-153639         2  2016-09-26 08:08:03
# 4           107913   A-107915         3  2016-05-19 22:08:20
# ...            ...        ...       ...                  ...
# 499995     1383866  A-1383897         2  2019-01-04 13:20:04
# 499996     1113299  A-1113325         3  2019-06-12 08:03:30
# 499997     1486192  A-1486224         2  2018-12-28 10:49:47
# 499998     2293957  A-2293997         2  2017-10-06 14:56:55
# 499999       81502    A-81504         2  2016-10-04 16:05:05
#
#                    End_Time State Country  Visibility(mi) Weather_Condition  \
# 0       2019-07-05 11:39:00    UT      US            10.0              Fair
# 1       2018-12-28 08:56:49    FL      US             7.0        Light Rain
# ...
