# %%
import pandas as pd

# %%
y_train = pd.read_csv('y_train.csv')
X_train = pd.read_csv('X_train.csv')
y_test = pd.read_csv('y_test.csv')
X_test = pd.read_csv('X_test.csv')

# %%
import tensorflow as tf

# %%
number_input_features = len(X_train.columns)
hidden_nodes_layer1 =  12
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))


nn.add(tf.keras.layers.Dense(units=4, activation="softmax"))

nn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_18 (Dense)             (None, 12)                6912
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 65
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 24
# ...
# Total params: 7,001
# Trainable params: 7,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train.values,y_train1,epochs=100)
# Out:
# Epoch 1/100
# 31250/31250 [==============================] - 42s 1ms/step - loss: 0.6141 - accuracy: 0.7174
# Epoch 2/100
# 31250/31250 [==============================] - 36s 1ms/step - loss: 0.5804 - accuracy: 0.7349
# Epoch 3/100
# 31250/31250 [==============================] - 36s 1ms/step - loss: 0.5705 - accuracy: 0.7403
# Epoch 4/100
# 31250/31250 [==============================] - 36s 1ms/step - loss: 0.5652 - accuracy: 0.7433
# Epoch 5/100
# 31250/31250 [==============================] - 36s 1ms/step - loss: 0.5620 - accuracy: 0.7453
# Epoch 6/100
# 31250/31250 [==============================] - 37s 1ms/step - loss: 0.5598 - accuracy: 0.7464
# Epoch 7/100
# 31250/31250 [==============================] - 37s 1ms/step - loss: 0.5582 - accuracy: 0.7472
# Epoch 8/100
# 31250/31250 [==============================] - 36s 1ms/step - loss: 0.5564 - accuracy: 0.7482
# Epoch 9/100
# 31250/31250 [==============================] - 37s 1ms/step - loss: 0.5551 - accuracy: 0.7492
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
on = OneHotEncoder(sparse = False)


y_train = pd.read_csv('y_train.csv')

y_train1 = on.fit_transform(y_train)

on = OneHotEncoder(sparse = False)
y_test = on.fit_transform(y_test)

# %%
model_loss, model_accuracy = nn.evaluate(X_test.values,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 7813/7813 - 10s - loss: 0.5478 - accuracy: 0.7544
# Loss: 0.5477901101112366, Accuracy: 0.7543839812278748
